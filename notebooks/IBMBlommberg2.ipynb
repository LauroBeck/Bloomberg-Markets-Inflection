# %%
from dataclasses import dataclass
from typing import Tuple, List


@dataclass
class AnalystTargets:
    average: float
    low: float
    high: float


@dataclass
class DividendInfo:
    quarterly: float
    yield_pct: float
    record_date: str


@dataclass
class MarketSnapshot:
    symbol: str
    price: float
    daily_low: float
    pct_change: float
    monthly_trend_pct: float
    rating: str
    targets: AnalystTargets
    dividend: DividendInfo
    strategic_focus: Tuple[str, ...]


def print_snapshot(s: MarketSnapshot):
    print("\n================ IBM MARKET SNAPSHOT ================\n")
    print(f"Symbol: {s.symbol}")
    print(f"Price: ${s.price}")
    print(f"Daily Low: ${s.daily_low}")
    print(f"Change: {s.pct_change:+.2f}%")
    print(f"Recent Trend: {s.monthly_trend_pct:.2f}%\n")

    print("Analyst Sentiment")
    print(f"Rating: {s.rating}")
    print(
        f"Targets → Avg: ${s.targets.average} | "
        f"Low: ${s.targets.low} | High: ${s.targets.high}\n"
    )

    print("Dividends")
    print(f"Quarterly Dividend: ${s.dividend.quarterly}")
    print(f"Yield: {s.dividend.yield_pct:.2f}%")
    print(f"Record Date: {s.dividend.record_date}\n")

    print("Strategic Focus")
    for item in s.strategic_focus:
        print(f"• {item}")

    print("\n=====================================================\n")


# -----------------------------------------------------
# Data based on your description
# -----------------------------------------------------

snapshot = MarketSnapshot(
    symbol="IBM",
    price=257.16,
    daily_low=253.80,
    pct_change=0.34,
    monthly_trend_pct=-11.0,
    rating="Hold (Downgraded Feb 18, 2026)",
    targets=AnalystTargets(
        average=320.38,
        low=218.00,
        high=380.00
    ),
    dividend=DividendInfo(
        quarterly=1.68,
        yield_pct=2.6,
        record_date="2026-02-10"
    ),
    strategic_focus=(
        "Artificial Intelligence",
        "Quantum Computing",
        "Quantum Advantage target by end of 2026",
        "FlashSystem with agentic AI"
    )
)

print_snapshot(snapshot)
# Out:
# ================ IBM MARKET SNAPSHOT ================
#
# Symbol: IBM
# Price: $257.16
# Daily Low: $253.8
# Change: +0.34%
# Recent Trend: -11.00%
#
# Analyst Sentiment
# Rating: Hold (Downgraded Feb 18, 2026)
# Targets → Avg: $320.38 | Low: $218.0 | High: $380.0
#
# Dividends
# Quarterly Dividend: $1.68
# Yield: 2.60%
# Record Date: 2026-02-10
#
# Strategic Focus
# • Artificial Intelligence
# • Quantum Computing
# • Quantum Advantage target by end of 2026
# • FlashSystem with agentic AI
#
# ...

# %% [markdown]
# # Task
# Create a Python data structure for IBM Cloud Partners' projections, populate it with example data including metrics like "revenue growth" and "market share", and then display these projections in a human-readable format. Finally, summarize the projections and identify key insights.

# %% [markdown]
# ## Define Data Structure for IBM Cloud Partners Projections
#
# ### Subtask:
# Create a new dataclass or extend an existing one to encapsulate key projection metrics relevant to IBM Cloud Partners, such as revenue growth, market share, or partner ecosystem health indicators.

# %% [markdown]
# **Reasoning**:
# The subtask requires defining a new dataclass for IBM Cloud Partners Projections with specific fields. This code block will create the dataclass as instructed.

# %%
from dataclasses import dataclass

@dataclass
class PartnersProjections:
    revenue_growth_pct: float
    market_share_pct: float
    partner_ecosystem_score: int
    projected_deals_count: int

print("PartnersProjections dataclass defined successfully.")
# Out:
# PartnersProjections dataclass defined successfully.

# %% [markdown]
# **Reasoning**:
# The next step is to populate the newly defined `PartnersProjections` dataclass with example data, as indicated by the overall task requirement to 'populate it with example data'.

# %%
cloud_partners_projections = PartnersProjections(
    revenue_growth_pct=15.5,
    market_share_pct=8.2,
    partner_ecosystem_score=92,
    projected_deals_count=1200
)

print("IBM Cloud Partners Projections data created successfully.")
# Out:
# IBM Cloud Partners Projections data created successfully.

# %% [markdown]
# **Reasoning**:
# The subtask requires displaying the populated `PartnersProjections` data in a human-readable format. This code block will define and call a print function to achieve this.

# %%
def print_partners_projections(projections: PartnersProjections):
    print("\n================ IBM CLOUD PARTNERS PROJECTIONS ================\n")
    print(f"Revenue Growth: {projections.revenue_growth_pct:.2f}%")
    print(f"Market Share: {projections.market_share_pct:.2f}%")
    print(f"Partner Ecosystem Score: {projections.partner_ecosystem_score}")
    print(f"Projected Deals Count: {projections.projected_deals_count}")
    print("\n================================================================\n")

print_partners_projections(cloud_partners_projections)
# Out:
# ================ IBM CLOUD PARTNERS PROJECTIONS ================
#
# Revenue Growth: 15.50%
# Market Share: 8.20%
# Partner Ecosystem Score: 92
# Projected Deals Count: 1200
#
# ...

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(14, 6))
fig.suptitle('IBM Cloud Partners Projections Overview', fontsize=16)

# --- Plot 1: Revenue Growth ---
metrics_growth = ['Revenue Growth']
values_growth = [cloud_partners_projections.revenue_growth_pct]

axes[0].bar(metrics_growth, values_growth, color='skyblue')
axes[0].set_ylabel('Percentage (%)')
axes[0].set_title('Projected Revenue Growth')
axes[0].set_ylim(0, max(values_growth) * 1.2)
axes[0].grid(axis='y', linestyle='--', alpha=0.7)
for i, value in enumerate(values_growth):
    axes[0].text(i, value + 0.5, f'{value:.2f}%', ha='center', va='bottom', fontsize=10)

# --- Plot 2: Projected Deals Count ---
metrics_deals = ['Projected Deals Count']
values_deals = [cloud_partners_projections.projected_deals_count]

axes[1].bar(metrics_deals, values_deals, color='lightgreen')
axes[1].set_ylabel('Count')
axes[1].set_title('Projected Deals Count')
axes[1].set_ylim(0, max(values_deals) * 1.2)
axes[1].grid(axis='y', linestyle='--', alpha=0.7)
for i, value in enumerate(values_deals):
    axes[1].text(i, value + 0.05 * max(values_deals), f'{int(value)}', ha='center', va='bottom', fontsize=10)

plt.tight_layout(rect=[0, 0.03, 1, 0.95]) # Adjust layout to prevent suptitle overlap
plt.show()

# %%
import matplotlib.pyplot as plt

# Prepare data for plotting
metrics = ['Projected Deals Count']
values = [cloud_partners_projections.projected_deals_count]

plt.figure(figsize=(6, 4))
plt.bar(metrics, values, color='lightgreen')
plt.ylabel('Count')
plt.title('Projected Deals Count for IBM Cloud Partners')
plt.ylim(0, max(values) * 1.2)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Add value on top of the bar
for i, value in enumerate(values):
    plt.text(i, value + 0.05 * max(values), f'{int(value)}', ha='center', va='bottom', fontsize=10)

plt.show()

# %%
import matplotlib.pyplot as plt

# Prepare data for plotting
metrics = ['Revenue Growth']
values = [cloud_partners_projections.revenue_growth_pct]

plt.figure(figsize=(6, 4))
plt.bar(metrics, values, color='skyblue')
plt.ylabel('Percentage (%)')
plt.title('Projected Revenue Growth for IBM Cloud Partners')
plt.ylim(0, max(values) * 1.2)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Add value on top of the bar
for i, value in enumerate(values):
    plt.text(i, value + 0.5, f'{value:.2f}%', ha='center', va='bottom', fontsize=10)

plt.show()

# %%
cloud_partners_projections = PartnersProjections(
    revenue_growth_pct=15.5,
    market_share_pct=8.2,
    partner_ecosystem_score=92,
    projected_deals_count=1200
)

print("IBM Cloud Partners Projections data created successfully.")

# %% [markdown]
# ## Summary and Key Insights for IBM Cloud Partners Projections
#
# Based on the provided projections for IBM Cloud Partners:
#
# *   **Revenue Growth**: The projected revenue growth is **15.50%**, indicating a strong expectation for expansion and increased financial performance within the cloud partners ecosystem.
# *   **Market Share**: The projected market share stands at **8.20%**, suggesting a current or target share of the relevant market segment. This metric is crucial for understanding the partners' competitive position.
# *   **Partner Ecosystem Score**: With a score of **92**, the partner ecosystem appears to be in excellent health. This high score likely reflects strong collaboration, high partner satisfaction, and effective program management.
# *   **Projected Deals Count**: The projection of **1200** deals highlights significant anticipated business activity and successful engagements through the partner channels.
#
# **Key Insights:**
#
# 1.  **Healthy Growth Trajectory**: The combination of high revenue growth and a substantial number of projected deals indicates a very positive outlook for the IBM Cloud Partners program.
# 2.  **Strong Ecosystem Foundation**: A high partner ecosystem score suggests that the infrastructure and support for partners are robust, which is essential for sustainable growth and deal closure.
# 3.  **Strategic Importance**: These projections underscore the critical role of cloud partners in IBM's overall growth strategy, especially in capturing market share and driving revenue.
# 4.  **Areas for Monitoring**: While projections are strong, continuous monitoring of market share against competitors and further analysis of the factors contributing to the high ecosystem score can help sustain and improve performance.

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Summarize the projections made for IBM Cloud Partners and highlight any key insights or potential areas for further analysis.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# The projections for IBM Cloud Partners are summarized as follows:
# *   **Revenue Growth:** A strong projected revenue growth of 15.50%.
# *   **Market Share:** A projected market share of 8.20%.
# *   **Partner Ecosystem Score:** An excellent score of 92, indicating a healthy ecosystem.
# *   **Projected Deals Count:** An anticipated 1200 deals.
#
# Key insights include a healthy growth trajectory and a strong ecosystem foundation, highlighting the strategic importance of cloud partners. Potential areas for further analysis involve continuous monitoring of market share against competitors and deeper investigation into factors contributing to the high ecosystem score.
#
# ### Data Analysis Key Findings
# *   A `PartnersProjections` dataclass was successfully defined to structure projection metrics.
# *   The projected revenue growth for IBM Cloud Partners is **15.50%**.
# *   The projected market share for IBM Cloud Partners is **8.20%**.
# *   The partner ecosystem health is indicated by a score of **92**.
# *   The projected number of deals is **1200**.
#
# ### Insights or Next Steps
# *   The combination of high revenue growth and a substantial number of projected deals suggests a very positive outlook for the IBM Cloud Partners program, indicating a healthy growth trajectory.
# *   The high partner ecosystem score (92) implies robust infrastructure and support for partners, which is crucial for sustainable growth and deal closure. Continuous monitoring of market share against competitors and further analysis of the factors contributing to this high ecosystem score can help sustain and improve performance.
